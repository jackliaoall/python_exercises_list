# %%
# !unzip common.zip
import sys, os
sys.path.append(os.pardir)
import numpy as np
from mnist import load_mnist
from two_layer_net import TwoLayerNet

(x_train, t_train), (x_test, y_test) = load_mnist(normalize=True, one_hot_label=True)

network = TwoLayerNet(input_size=784, hidden_size=50, output_size=10)

x_batch = x_train[:3]
t_batch = t_train[:3]

grad_numerical = network.grad_numerical(x_batch, t_batch)
grad_backprop = network.gradient(x_batch, t_batch)

for key in grad_numerical.keys():
    diff = np.average( np.abs(grad_backprop[key] - grad_numerical[key]) )
    print(key + ":" + str(diff))
# Out:
# Archive:  common.zip
#    creating: common/
#   inflating: common/functions.py
#   inflating: common/gradient.py
#   inflating: common/layers.py
#   inflating: common/multi_layer_net.py
#   inflating: common/multi_layer_net_extend.py
#   inflating: common/optimizer.py
#   inflating: common/trainer.py
#   inflating: common/util.py
#  extracting: common/__init__.py
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-f3588f69b0cc> in <module>()
#      13 t_batch = t_train[:3]
#      14
# ---> 15 grad_numerical = network.grad_numerical(x_batch, t_batch)
#      16 grad_backprop = network.gradient(x_batch, t_batch)
#      17
#
# AttributeError: 'TwoLayerNet' object has no attribute 'grad_numerical'
